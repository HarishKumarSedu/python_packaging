# %%
# !pip install mlrun
# Out:
# ...
#   Using cached mlrun-1.6.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
# ...
#   Using cached aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# ...
#   Using cached aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached kfp-1.8.22.tar.gz (304 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached nuclio_jupyter-0.9.16-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached pandas-2.1.4-cp311-cp311-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached pyarrow-14.0.2-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# ...
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# ...
